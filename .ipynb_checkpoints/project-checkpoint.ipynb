# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
import statsmodels.formula.api as smf

# %%
data = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/masculinity-survey.csv")

one_hot = pd.read_csv("one-hot-responses.csv")
# Very masculine, Somewhat masculine, Not very masculine, Not at all masculine
masculinity_scale = [col for col in one_hot.columns if col.startswith('q0001')]
# Straight, Gay, Bisexual, Other
sexuality_scale = [col for col in one_hot.columns if col.startswith('q0026')]
# print(masculinity_scale)
print(sexuality_scale)

# top n pca
n = 20
predictors = [one_hot.columns[i] for i in range(7, len(one_hot.columns))]
X = one_hot[predictors].values.T
n_i, n_j = X.shape
stds = np.std(X, axis=1)
stds = np.repeat(np.reshape(stds, (-1,1)), n_j, axis=1)
S = X/stds
pcs = PCA(n_components=n).fit_transform(S.T)
df_pcs = pd.DataFrame(pcs, columns=['PC'+str(i+1) for i in range(n)])

# predict whether the person was gay based on their survey responses
df_pcs['y'] = one_hot['q0026_Gay'].values
# Out:
# ['q0026_Bisexual', 'q0026_Gay', 'q0026_No answer', 'q0026_Other', 'q0026_Straight']

# %%
# 10 fold cross validation, linear regression
mean_mses = []
kf = KFold(n_splits=10, shuffle=True)
pc_numbers = [i+1 for i in range(n)]
# linear models using top k=1,2,3,...,20
for num_pc in pc_numbers:
    # do 10-fold cross validation
    train_mses = []
    test_mses = []
    for train_idx, test_idx in kf.split(df_pcs):
        df_train = df_pcs.iloc[train_idx, :]
        df_test = df_pcs.iloc[test_idx, :]
        
        # generate formula
        formula = 'y ~ 1'
        for num in range(1, num_pc+1):
            formula += (' + PC%d' % num)
            
        # fit model with df_train
        res = smf.ols(formula=formula, data=df_train).fit()

        # MSE of training set
        train_pred = res.predict(df_train)
        mse_train = np.mean((train_pred - df_train.y)**2)

        # MSE of test set
        test_pred = res.predict(df_test)
        mse_test = np.mean((test_pred - df_test.y)**2)

        # store results
        train_mses.append(mse_train)
        test_mses.append(mse_test)



    # report average training MSE and testing MSE
    mean_train_mse = np.mean(train_mses)
    mean_test_mse = np.mean(test_mses)
    
    mean_mses.append({'num_pc': num_pc,
                      'formula': formula,
                    'mean_train_mse': mean_train_mse,
                     'mean_test_mse': mean_test_mse})
    
    
df_res = pd.DataFrame(mean_mses)
df_res

# %%
fig, ax = plt.subplots()
ax.plot(df_res.num_pc, df_res.mean_train_mse, label='training set')
ax.plot(df_res.num_pc, df_res.mean_test_mse, label='test set')
ax.legend()
ax.set_xticks(df_res.num_pc.values)
ax.set_xlabel('number of top PC used')
ax.set_ylabel('Mean squared error')
plt.show()
best_model = df_res.loc[df_res.mean_test_mse.argmin()]
best_model
# Out:
# /Users/Shirley/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   if __name__ == '__main__':
# formula           y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...
# mean_test_mse                                             0.0256007
# mean_train_mse                                            0.0246706
# num_pc                                                           20
# Name: 19, dtype: object

# %%
# 10 fold cross validation, logistic regression
mean_mses = []
kf = KFold(n_splits=10, shuffle=True)
pc_numbers = [i+1 for i in range(n)]
# linear models using top k=1,2,3,...,20
for num_pc in pc_numbers:
    # do 10-fold cross validation
    train_mses = []
    test_mses = []
    for train_idx, test_idx in kf.split(df_pcs):
        df_train = df_pcs.iloc[train_idx, :]
        df_test = df_pcs.iloc[test_idx, :]
        
        # generate formula
        formula = 'y ~ 1'
        for num in range(1, num_pc+1):
            formula += (' + PC%d' % num)
            
        # fit model with df_train
        res = smf.logit(formula=formula, data=df_train).fit()

        # MSE of training set
        train_pred = 1*(res.predict(df_train) > 0.5)
        mse_train = np.mean((train_pred - df_train.y)**2)

        # MSE of test set
        test_pred = 1*(res.predict(df_test) > 0.5)
        mse_test = np.mean((test_pred - df_test.y)**2)

        # store results
        train_mses.append(mse_train)
        test_mses.append(mse_test)



    # report average training MSE and testing MSE
    mean_train_mse = np.mean(train_mses)
    mean_test_mse = np.mean(test_mses)
    
    mean_mses.append({'num_pc': num_pc,
                      'formula': formula,
                    'mean_train_mse': mean_train_mse,
                     'mean_test_mse': mean_test_mse})
    
    
df_res = pd.DataFrame(mean_mses)
df_res
# Out:
# Optimization terminated successfully.
#          Current function value: 0.255171
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.240471
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.241123
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.262379
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.258709
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.251426
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.253635
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.245916
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.246373
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.241051
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.199120
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.190102
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.186745
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.184036
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.188289
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.193333
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.192748
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.179491
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.197547
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.180677
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.136080
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.135040
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.136851
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133833
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.141794
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.136887
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.142177
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.136420
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.146402
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.140183
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.133726
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.127997
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130573
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131012
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130094
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.131804
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.129221
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.129399
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.127209
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.135434
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130983
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.126279
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130335
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.124122
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.128442
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132069
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.130011
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.117071
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.128728
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.122791
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.125661
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.123775
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.119796
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.126797
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.124469
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.122965
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.128657
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.120941
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.126511
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.116848
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.107788
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.103768
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.102759
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.106123
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.098660
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.102819
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.106901
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.103535
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.103005
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.104690
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.098391
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.101592
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.106711
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.106825
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.100157
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.104332
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.106161
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.102806
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.104537
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.103745
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.094831
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.097028
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.086052
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.098033
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.091251
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.093562
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.098363
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.091150
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.094350
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.093459
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.088499
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.091406
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.096572
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.097398
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.088779
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.097596
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.096376
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.095906
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.094551
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.088511
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085216
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083835
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.091004
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.090737
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.081308
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.089332
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.092131
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.084740
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083203
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085545
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082496
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.088092
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084939
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.087093
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.082312
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.089229
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.084493
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.089054
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085592
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085786
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071378
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077151
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.068165
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.066732
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.068539
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071310
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072748
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077559
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075461
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.069341
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.059958
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.055710
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.063807
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.053243
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.061352
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.057207
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.060483
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.059877
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.061084
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.057799
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.060980
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.058184
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.053955
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.057653
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.058648
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.059547
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.062618
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.059643
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.054242
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.060855
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.053187
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.057876
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.062861
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.054053
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.060454
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.061212
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.057525
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.056067
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.058190
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.056018
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.052074
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.050663
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.047011
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.053786
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.051667
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.049321
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.047386
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.050575
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.051044
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.049169
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044409
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.039444
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045019
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045994
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.036929
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.039134
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042862
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042659
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042833
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042877
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.044907
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.040237
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042998
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042338
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.040239
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042566
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.043476
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.041225
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.039356
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.043085
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.046416
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.039704
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.034279
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.045230
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.040294
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042344
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.039691
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042302
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.042383
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.043581
#          Iterations 11
#                                               formula  mean_test_mse  \
# 0                                         y ~ 1 + PC1       0.068752
# 1                                   y ~ 1 + PC1 + PC2       0.074316
# 2                             y ~ 1 + PC1 + PC2 + PC3       0.060663
# 3                       y ~ 1 + PC1 + PC2 + PC3 + PC4       0.055751
# 4                 y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5       0.050778
# 5           y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6       0.048915
# 6     y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7       0.037156
# 7   y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.037773
# 8   y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.039629
# 9   y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.039000
# 10  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.039629
# 11  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.039004
# 12  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.035289
# 13  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.035293
# 14  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.033437
# 15  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.034066
# 16  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.026639
# 17  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.019209
# 18  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.021061
# 19  y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...       0.019811
#
#     mean_train_mse  num_pc
# 0         0.068731       1
# 1         0.073822       2
# 2         0.060062       3
# 3         0.054214       4
# 4         0.049467       5
# 5         0.047472       6
# 6         0.035845       7
# 7         0.036670       8
# 8         0.034813       9
# 9         0.035707      10
# 10        0.034537      11
# 11        0.035432      12
# 12        0.030271      13
# 13        0.027313      14
# 14        0.026832      15
# 15        0.025800      16
# 16        0.020709      17
# 17        0.015342      18
# 18        0.015205      19
# 19        0.014860      20

# %%
fig, ax = plt.subplots()
ax.plot(df_res.num_pc, df_res.mean_train_mse, label='training set')
ax.plot(df_res.num_pc, df_res.mean_test_mse, label='test set')
ax.legend()
ax.set_xticks(df_res.num_pc.values)
ax.set_xlabel('number of top PC used')
ax.set_ylabel('Mean squared error')
plt.show()
best_model = df_res.loc[df_res.mean_test_mse.argmin()]
best_model
# Out:
# /Users/Shirley/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   if __name__ == '__main__':
# formula           y ~ 1 + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC...
# mean_test_mse                                             0.0192086
# mean_train_mse                                            0.0153422
# num_pc                                                           18
# Name: 17, dtype: object
